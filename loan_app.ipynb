# %%
import pandas as pd
import numpy as np

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
dfloan = pd.read_csv('loan.csv')
dfloan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
## Machine Learning Libararies
#The above data is used to build a system to find out or predict if a customer is eligible to get a loan
#Label in coding

# %%
#Data Inspection
dfloan.shape
# Out:
# (614, 13)

# %%
#checking for missing values
dfloan.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
dfloan.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
columns = ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
       'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
       'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status']

# %%
#Using Mode to fill up missing values

dfloan['Gender'] = dfloan['Gender'].fillna(dfloan['Gender'].mode()[0])
dfloan['Married'] = dfloan['Married'].fillna(dfloan['Married'].mode()[0])
dfloan['Dependents'] = dfloan['Dependents'].fillna(dfloan['Dependents'].mode()[0])
dfloan['Self_Employed'] = dfloan['Self_Employed'].fillna(dfloan['Self_Employed'].mode()[0])
dfloan['LoanAmount'] = dfloan['LoanAmount'].fillna(dfloan['LoanAmount'].mode()[0])
dfloan['Loan_Amount_Term'] = dfloan['Loan_Amount_Term'].fillna(dfloan['Loan_Amount_Term'].mode()[0])
dfloan['Credit_History'] = dfloan['Credit_History'].fillna(dfloan['Credit_History'].mode()[0])

# %%
dfloan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       120.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
dfloan.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings('ignore', category=UserWarning)

# %%
dfloan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       120.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
dfloan['Dependents'] =dfloan['Dependents'].replace({'3+':'3'})

# %%
#Checking Unique Values
dfloan['Property_Area'] =dfloan['Property_Area'].replace({'2':'2'})

# %%
#converting columns with text to numerical values for the machine to be able to read
dfloan.replace({'Gender': {'Female': 0, 'Male':1}, 
            'Married': {'Yes': 1, 'No': 0}, 
            'Education': {'Graduate': 1, 'Not Graduate': 0},
            'Self_Employed':{'Yes':1, 'No': 0,},
            'Loan_Status': {'Y': 1, 'N':0},
           'Property_Area':{'Urban': 2, 'Rural': 0, 'Semiurban': 1}}, inplace = True)
# Out:
# C:\Users\Richard\AppData\Local\Temp\ipykernel_6548\3710347453.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dfloan.replace({'Gender': {'Female': 0, 'Male':1},

# %%
#Converting columns with text to numerical values for the machine to be able to read
dfloan.replace({'Gender': {'Female': 0, 'Male':1}, 
            'Married': {'Yes': 1, 'No': 0}, 
            'Education': {'Graduate': 1, 'Not Graduate': 0},
            'Self_Employed': {'Yes': 1, 'No': 0}, 
            'Loan_Status': {'Y': 1, 'N':0},
             'Property_Area':{'Urban': 2, 'Rural': 0, 'Semiurban': 1}}, inplace = True)

# %%
dfloan.head()
# Out:
#     Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0  LP001002       1        0          0          1              0
# 1  LP001003       1        1          1          1              0
# 2  LP001005       1        1          0          1              1
# 3  LP001006       1        1          0          0              0
# 4  LP001008       1        0          0          1              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       120.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History  Property_Area  Loan_Status
# 0             1.0              2            1
# 1             1.0              0            0
# ...

# %%
# Droping Unwanted column
dfloan.drop(columns = 'Loan_ID', inplace = True)

# %%
dfloan.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0          0          1              0             5849
# 1       1        1          1          1              0             4583
# 2       1        1          0          1              1             3000
# 3       1        1          0          0              0             2583
# 4       1        0          0          1              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       120.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#    Property_Area  Loan_Status
# 0              2            1
# 1              0            0
# ...

# %% [markdown]
# # Seperating the input from Target

# %%
x = dfloan.drop(columns = 'Loan_Status', axis = 1) 
y = dfloan['Loan_Status']

# %%
x
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0          0          1              0             5849
# 1         1        1          1          1              0             4583
# 2         1        1          0          1              1             3000
# 3         1        1          0          0              0             2583
# 4         1        0          0          1              0             6000
# ..      ...      ...        ...        ...            ...              ...
# 609       0        0          0          1              0             2900
# 610       1        1          3          1              0             4106
# 611       1        1          1          1              0             8072
# 612       1        1          2          1              0             7583
# 613       0        0          0          1              1             4583
#
# ...

# %% [markdown]
# # Train Test Split

# %% [raw]
# #Inbalance Data is used to identify if a data is balanced, upsampling is used to make a data be balanced.
#
# 80% for training data
# 20& for test data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 2)

# %%
#Checking the shape of data
dfloan.shape, x_train.shape, x_test.shape
# Out:
# ((614, 12), (491, 11), (123, 11))

# %% [markdown]
# # Model Training

# %%
x.shape
# Out:
# (614, 11)

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int64

# %%
y.value_counts()
# Out:
# Loan_Status
# 1    422
# 0    192
# Name: count, dtype: int64

# %% [markdown]
# # Selecting our Model

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
# Using Support Vector Machine
classifier = svm.SVC(kernel = 'linear')

# %%
#Fitting our training data into the classifier
#x_training data and y_trainis the label
classifier.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
x_train_prediction = classifier.predict(x_train)

training_data_accuracy = accuracy_score(x_train_prediction, y_train)

# %%
#Accuracy score of the train data

print('Accuracy score of the Training Data is:', training_data_accuracy)
# Out:
# Accuracy score of the Training Data is: 0.8085539714867617

# %%
#Evaluating the model to know the accuracy of the test data

x_test_prediction = classifier.predict(x_test)

test_data_accuracy = accuracy_score(x_test_prediction, y_test)

# %%
print('Accuracy score of the Test Data is:', test_data_accuracy)
# Out:
# Accuracy score of the Test Data is: 0.7642276422764228

# %%
#Confusion Matrix is used for evaluation of the performance of a Dataset
#Precision is the ratio of two positive

# %%
#Making a predictive system
input_data = (1,0,0,1,0,5849,0.0,120.0,360.0,1.0,2)

#Changing the input data to numpy arrray since the processing is more efficient
convert_data_to_numpy = np.asarray(input_data)

#reshaping the array as we are predicting for one data point
#parameter for reshaping ==> '.reshape(1, -1)'
reshape_input_data = convert_data_to_numpy.reshape(1, -1)



prediction = classifier.predict(reshape_input_data)
print(prediction)

if prediction==0:
    print("We're sorry, Your Loan has not Approved.")
else:
    print('Congratulations, Your Loan has been Approved.')
# Out:
# [1]
# Congratulations, Your Loan has been Approved.

# %%
import pickle

# %%
classifier
# Out:
# SVC(kernel='linear')

# %%
#Creating a variable to save the trained model
filename = 'loan_classifier.sav'
#standard_scaler = 'scaler.sav'

# %%
pickle.dump(classifier,open('loan_classifier.sav', 'wb'))
#pickle.dumb

# %%
#Loading the saved model
loaded_model = pickle.load(open('loan_classifier.sav', 'rb'))
#Standard_scaler = pickle.load(open('scaler.sav', 'rb'))

# %%
#Making a Precictive system
input_data = (1,0,0,1,0,5849,0.0,360.0,1.0,2)

#Changing the input data to numpy array since the processing is more eeficient
convert_data_to_numpy = np.array(input_data)

# %%
#Making a predictive system
input_data = (1,0,0,1,0,5849,0.0,120.0,360.0,1.0,2)

#Changing the input data to numpy arrray since the processing is more efficient
convert_data_to_numpy = np.asarray(input_data)

#reshaping the array as we are predicting for one data point
#parameter for reshaping ==> '.reshape(1, -1)'
reshape_input_data = convert_data_to_numpy.reshape(1, -1)



prediction = loaded_model.predict(reshape_input_data)
print(prediction)

if prediction==0:
    print("We're sorry, Your Loan has not Approved.")
else:
    print('Congratulations, Your Loan has been Approved.')
# Out:
# [1]
# Congratulations, Your Loan has been Approved.
